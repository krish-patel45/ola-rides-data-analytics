# %%
import pandas as pd 
import numpy as np

# %%
cr=pd.read_csv("C:\\Users\\krish chaudhary\\OneDrive\\ドキュメント\\OLA PROJECT\\Bookings-100000-Rows.csv")

# %%
cr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  str
#  1   Time                        103024 non-null  str
#  2   Booking_ID                  103024 non-null  str
#  3   Booking_Status              103024 non-null  str
#  4   Customer_ID                 103024 non-null  str
#  5   Vehicle_Type                103024 non-null  str
#  6   Pickup_Location             103024 non-null  str
#  7   Drop_Location               103024 non-null  str
#  8   V_TAT                       63967 non-null   float64
#  9   C_TAT                       63967 non-null   float64
#  10  Canceled_Rides_by_Customer  10499 non-null   str
#  11  Canceled_Rides_by_Driver    18434 non-null   str
#  12  Incomplete_Rides            63967 non-null   str
# ...

# %%
cr.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                         39057
# C_TAT                         39057
# Canceled_Rides_by_Customer    92525
# Canceled_Rides_by_Driver      84590
# Incomplete_Rides              39057
# Incomplete_Rides_Reason       99098
# Booking_Value                     0
# Payment_Method                39057
# Ride_Distance                     0
# Driver_Ratings                39057
# Customer_Rating               39057
# dtype: int64

# %%
cr.head()
# Out:
#                   Date      Time     Booking_ID        Booking_Status  \
# 0  2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1  2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2  2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3   2024-07-22 3:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4   2024-07-02 9:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  ...  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN  ...
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0  ...
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0  ...
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN  ...
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0  ...
#
#        Canceled_Rides_by_Driver Incomplete_Rides Incomplete_Rides_Reason  \
# ...

# %%
cr.drop(['Unnamed: 20','Vehicle Images'], axis=1, inplace=True)

# %%
cr['Payment_Method']=cr['Payment_Method'].fillna('Not Applicable', inplace=True)
# Out:
# C:\Users\krish chaudhary\AppData\Local\Temp\ipykernel_9712\2268544560.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   cr['Payment_Method']=cr['Payment_Method'].fillna('Not Applicable', inplace=True)

# %%
cr['Payment_Method'].isnull().sum()
# Out:
# np.int64(0)

# %%
cr['Driver_Ratings']=cr['Driver_Ratings'].fillna(0, inplace=True)
cr['Customer_Rating']=cr['Customer_Rating'].fillna(0, inplace=True)
# Out:
# C:\Users\krish chaudhary\AppData\Local\Temp\ipykernel_9712\445431611.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   cr['Driver_Ratings']=cr['Driver_Ratings'].fillna(0, inplace=True)
# ...

# %%
cr['V_TAT']=cr['V_TAT'].fillna(0, inplace=True)
cr['C_TAT']=cr['C_TAT'].fillna(0, inplace=True)
# Out:
# C:\Users\krish chaudhary\AppData\Local\Temp\ipykernel_9712\1326064879.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   cr['V_TAT']=cr['V_TAT'].fillna(0, inplace=True)
# ...

# %%
cr['Incomplete_Rides']=cr['Incomplete_Rides'].fillna('No', inplace=True)
# Out:
# C:\Users\krish chaudhary\AppData\Local\Temp\ipykernel_9712\3890527158.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   cr['Incomplete_Rides']=cr['Incomplete_Rides'].fillna('No', inplace=True)

# %%
cr['Incomplete_Rides_Reason']=cr['Incomplete_Rides_Reason'].fillna('Not Applicable', inplace=True)
# Out:
# C:\Users\krish chaudhary\AppData\Local\Temp\ipykernel_9712\3056454949.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   cr['Incomplete_Rides_Reason']=cr['Incomplete_Rides_Reason'].fillna('Not Applicable', inplace=True)

# %%
cr.isnull().sum()
# Out:
# Date                          0
# Time                          0
# Booking_ID                    0
# Booking_Status                0
# Customer_ID                   0
# Vehicle_Type                  0
# Pickup_Location               0
# Drop_Location                 0
# V_TAT                         0
# C_TAT                         0
# Canceled_Rides_by_Customer    0
# Canceled_Rides_by_Driver      0
# Incomplete_Rides              0
# Incomplete_Rides_Reason       0
# Booking_Value                 0
# Payment_Method                0
# Ride_Distance                 0
# Driver_Ratings                0
# Customer_Rating               0
# dtype: int64

# %%
cr['Canceled_Rides_by_Customer']=cr['Canceled_Rides_by_Customer'].fillna('Not Applicable', inplace=True)
cr['Canceled_Rides_by_Driver']=cr['Canceled_Rides_by_Driver'].fillna('Not Applicable', inplace=True)
# Out:
# C:\Users\krish chaudhary\AppData\Local\Temp\ipykernel_9712\3589879331.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   cr['Canceled_Rides_by_Customer']=cr['Canceled_Rides_by_Customer'].fillna('Not Applicable', inplace=True)
# ...

# %%
cr.duplicated().sum()
# Out:
# np.int64(0)

# %%
cr.to_csv('ola.csv')
